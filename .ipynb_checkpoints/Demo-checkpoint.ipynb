# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import ListedColormap

# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# dataset
k = 3
 = 100
data, origin_label = make_blobs(n_samples=200,centers=k+2)

cm = plt.cm.get_cmap("viridis")
my_cmap = cm(np.linspace(0,1,k))
# Set alpha
my_cmap[:, -1] = 0.3
# Create new colormap
my_cmap = ListedColormap(my_cmap)

# %%
plt.scatter(data[:,0],data[:,1])

# %%
labels = np.zeros([max_steps,data.shape[0]], dtype = np.float64)
distance = np.zeros([data.shape[0],k], dtype = np.float64)
centers = np.zeros([max_steps+1,k,data.shape[1]], dtype = np.float64)

fig, ax = plt.subplots()

# %%
# random choose center
centers[0] = data[ np.random.randint(data.shape[0],size=k) ]
print(centers[0])
# Out:
# [[-4.69195231 -7.59349013]
#  [-3.72923632 -5.34085348]
#  [-6.88081607  7.56214633]]

# %%
for i in range(max_steps):
    # calculate distance
    for j, c in enumerate(centers[i]):
        distance[:,j] = np.linalg.norm(data - c, axis = 1)
    # assign labels
    labels[i] = np.argmin(distance, axis=1)
    # re-calculate centers
    for j in range(k):
        centers[i+1,j] = np.mean(data[labels[i] == j], axis = 0)

# %%
plt.scatter(data[:,0],data[:,1], c=labels[i], cmap = my_cmap,marker = '.', lw=0.5)
plt.scatter(centers[k,:,0],centers[k,:,1], c = range(k), cmap = "viridis",  marker='x', lw=3,s=60)

# %%
scatter = ax.scatter(data[:,0],data[:,1], c=labels[i], cmap = my_cmap,marker = '.', lw=0.5)
scatter = ax.scatter(centers[0,:,0],centers[0,:,1], c = range(k), cmap = "viridis",  marker='x', lw=3,s=60)

def update(i):
    #print(i,type(data),type(centers[i+1]))
    offset = np.concatenate([data,centers[i+1]])
    scatter.set_offsets(offset)
    ax.set_title(f'Step: {i}')

# %%
ani = animation.FuncAnimation(fig, update, frames=range(max_steps),interval=50)

writer = animation.FFMpegWriter(
     fps=15, metadata=dict(artist='Me'), bitrate=1800)
ani.save("movie.mp4")
